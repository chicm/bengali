# %%
import os
import pandas as pd
import numpy as np
import time, gc
import cv2
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pretrainedmodels
from argparse import Namespace
from sklearn.utils import shuffle
from apex import amp
from sklearn.model_selection import StratifiedKFold
from efficientnet_pytorch import EfficientNet
from cvcore.data.auto_augment import RandAugment
from PIL import Image
from utils import bn_update, moving_average, copy_model

# %%
# !ls /home/chec/data/bengali
# Out:
# ls: cannot access '/home/chec/data/bengali': No such file or directory

# %%
#!ls /home/chec/data/bengali

# %%
DATA_DIR = '/mnt/chicm/data/bengali'

# %%
train_df = pd.read_csv(f'{DATA_DIR}/train.csv')
test_df = pd.read_csv(f'{DATA_DIR}/test.csv')
class_map_df = pd.read_csv(f'{DATA_DIR}/class_map.csv')
sample_sub_df = pd.read_csv(f'{DATA_DIR}/sample_submission.csv')

# %%
train_df.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
from torch.utils.data.sampler import WeightedRandomSampler

def class_balanced_sampler(labels):
    class_counts = np.bincount(labels)
    total_samples = len(labels)
    sample_weights = np.zeros_like(labels).astype(np.float32)
    for idx, label in enumerate(labels):
        sample_weights[idx] = total_samples / class_counts[label]
    # return sample_weights
    sampler = WeightedRandomSampler(weights=sample_weights,
        num_samples=total_samples)
    return sampler

# %%
HEIGHT = 137
WIDTH = 236

# %%
#import albumentations as albu
def get_train_augs():
    return RandAugment(n=2, m=27)

# %%
#plt.imshow(x)
finetune_class = 'vowel_diacritic'

# %%
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms


class BengaliDataset(Dataset):
    def __init__(self, df, img_df, train_mode=True, test_mode=False):
        self.df = df
        self.img_df = img_df
        self.train_mode = train_mode
        self.test_mode = test_mode

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img = self.get_img(row.image_id)
        orig_img = img.copy()
        #print(img.shape)
        if self.train_mode:
            augs = get_train_augs()
            #img = augs(image=img)['image']
            img = np.asarray(augs(Image.fromarray(img)))
        
        img = np.expand_dims(img, axis=-1)
        orig_img = np.expand_dims(orig_img, axis=-1)
        
        #print('###', img.shape)
        #img = np.concatenate([img, img, img], 2)
        #print('>>>', img.shape)
        
        # taken from https://www.kaggle.com/iafoss/image-preprocessing-128x128
        #MEAN = [ 0.06922848809290576,  0.06922848809290576,  0.06922848809290576]
        #STD = [ 0.20515700083327537,  0.20515700083327537,  0.20515700083327537]
        
        img = transforms.functional.to_tensor(img)
        orig_img = transforms.functional.to_tensor(orig_img)
        
        #img = transforms.functional.normalize(img, mean=MEAN, std=STD)
        
        if self.test_mode:
            return img
        elif self.train_mode:
            return img, orig_img, torch.tensor([row.grapheme_root, row.vowel_diacritic, row.consonant_diacritic, row.word_label])
        else:
            return img, torch.tensor([row.grapheme_root, row.vowel_diacritic, row.consonant_diacritic, row.word_label])
                    
    def get_img(self, img_id):
        return 255 - self.img_df.loc[img_id].values.reshape(HEIGHT, WIDTH).astype(np.uint8)

    def __len__(self):
        return len(self.df)
    
def get_train_val_loaders(batch_size=4, val_batch_size=4, ifold=0, dev_mode=False):
    print('fold:', ifold)
    train_df = pd.read_csv(f'{DATA_DIR}/train.csv')

    train_df = shuffle(train_df, random_state=1234)

    grapheme_words = np.unique(train_df.grapheme.values)
    grapheme_words_dict = {grapheme: i for i, grapheme in enumerate(grapheme_words)}
    train_df['word_label'] = train_df['grapheme'].map(lambda x: grapheme_words_dict[x])

    print(train_df.shape)

    if dev_mode:
        img_df = pd.read_parquet(f'{DATA_DIR}/train_image_data_0.parquet').set_index('image_id')
        train_df = train_df.iloc[:1000]
    else:
        img_dfs = [pd.read_parquet(f'{DATA_DIR}/train_image_data_{i}.parquet') for i in range(4)]
        img_df = pd.concat(img_dfs, axis=0).set_index('image_id')
    print(img_df.shape)
    #split_index = int(len(train_df) * 0.9)
    
    #train = train_df.iloc[:split_index]
    #val = train_df.iloc[split_index:]
    
    kf = StratifiedKFold(5, random_state=1234, shuffle=True)
    for i, (train_idx, val_idx) in enumerate(kf.split(train_df, train_df['grapheme_root'].values)):
        if i == ifold:
            #print(val_idx)
            train = train_df.iloc[train_idx]
            val = train_df.iloc[val_idx]
            break
    assert i == ifold
    print(train.shape, val.shape)
    
    train_ds = BengaliDataset(train, img_df, True, False)
    val_ds = BengaliDataset(val, img_df, False, False)
    
    sampler = class_balanced_sampler(train[finetune_class])
    print('sampler length: {}'.format(sampler.weights.shape))

    
    train_loader = DataLoader(
        train_ds, batch_size=batch_size, shuffle=False, num_workers=8, drop_last=False, pin_memory=True, sampler=sampler)
    train_loader.num = len(train_ds)

    val_loader = DataLoader(
        val_ds, batch_size=val_batch_size, shuffle=False, num_workers=8, drop_last=False, pin_memory=True)
    val_loader.num = len(val_ds)

    return train_loader, val_loader

# %%
#train_loader, val_loader = get_train_val_loaders()

# %%
#for x in train_loader:
#    print(x)
#    break

# %% [markdown]
# # model

# %%
#import pretrainedmodels

# %%
#model_name = 'resnet50' # could be fbresnet152 or inceptionresnetv2
#model = pretrainedmodels.__dict__[model_name](num_classes=1000, pretrained='imagenet').cuda()
#model.eval()

# %%
from argparse import Namespace
import timm
from timm.models.activations import Swish, Mish
from timm.models.adaptive_avgmax_pool import SelectAdaptivePool2d

MEAN = [ 0.06922848809290576 ]
STD = [ 0.20515700083327537 ]

# %%
class BengaliNetOld(nn.Module):
    def __init__(self, backbone_name='se_resnext50_32x4d'):
        super(BengaliNetOld, self).__init__()
        self.n_grapheme = 168
        self.n_vowel = 11
        self.n_consonant = 7
        self.n_word = 1295
        self.backbone_name = backbone_name
        
        self.num_classes = self.n_grapheme + self.n_vowel + self.n_consonant + self.n_word
        
        self.backbone = pretrainedmodels.__dict__[self.backbone_name](num_classes=1000, pretrained='imagenet')
        self.fc = nn.Linear(self.backbone.last_linear.in_features, self.num_classes)
        
        self.num_p2_features = self.backbone.layer2[-1].se_module.fc2.out_channels
        self.num_p3_features = self.backbone.layer3[-1].se_module.fc2.out_channels
        self.p2_head = nn.Conv2d(self.num_p2_features, self.num_p2_features * 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
        self.p3_head = nn.Conv2d(self.num_p3_features, self.num_p3_features * 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
        self.bn2 = nn.BatchNorm2d(self.num_p2_features * 4)
        self.bn3 = nn.BatchNorm2d(self.num_p3_features * 4)
        self.act2 = Swish()
        self.act3 = Swish()
        
        self.fc_aux1 = nn.Linear(self.num_p3_features * 4, self.num_classes)
        self.fc_aux2 = nn.Linear(self.num_p2_features * 4, self.num_classes)
        
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        
        for fc in [self.fc, self.fc_aux1, self.fc_aux2]:
            nn.init.zeros_(fc.bias.data)

        print('init model4')
        
    def features(self, x):
        x = self.backbone.layer0(x); #print(x.size())
        x = self.backbone.layer1(x); #print(x.size())
        x = self.backbone.layer2(x); p2 = x; p2 = self.p2_head(p2); p2 = self.bn2(p2); p2 = self.act2(p2) #print(x.size())
        x = self.backbone.layer3(x); p3 = x; p3 = self.p3_head(p3); p3 = self.bn3(p3); p3 = self.act3(p3) #print(x.size())
        x = self.backbone.layer4(x); #print(x.size())
        return x, p2, p3
        
    def logits(self, x, p2, p3):
        x = self.avg_pool(x)
        #x = F.dropout2d(x, 0.2, self.training)
        x = torch.flatten(x, 1)
        
        p2 = self.avg_pool(p2)
        p2 = torch.flatten(p2, 1)
        
        p3 = self.avg_pool(p3)
        p3 = torch.flatten(p3, 1)
        return self.fc(x), self.fc_aux1(p3), self.fc_aux2(p2)
    
    def forward(self, x):
        x = F.interpolate(x, size=(224,224), mode='bilinear', align_corners=False)
        for i in range(len(x)):
            transforms.functional.normalize(x[i], mean=MEAN, std=STD, inplace=True)
        x = torch.cat([x,x,x], 1)
        #x = self.conv0(x)
        #print(x.size())
        x, p2, p3 = self.features(x)
        x, logits_aux1, logits_aux2 = self.logits(x, p2, p3)

        return x, logits_aux1, logits_aux2

# %%
class BengaliNet(nn.Module):
    def __init__(self, backbone_name='se_resnext50_32x4d'):
        super(BengaliNet, self).__init__()
        self.n_grapheme = 168
        self.n_vowel = 11
        self.n_consonant = 7
        self.n_word = 1295
        self.backbone_name = backbone_name
        
        self.num_classes = self.n_grapheme + self.n_vowel + self.n_consonant + self.n_word
        
        self.backbone = pretrainedmodels.__dict__[self.backbone_name](num_classes=1000, pretrained='imagenet')
        
        self.num_p2_features = self.backbone.layer2[-1].se_module.fc2.out_channels
        self.num_p3_features = self.backbone.layer3[-1].se_module.fc2.out_channels
        self.p2_head = nn.Conv2d(self.num_p2_features, self.num_p2_features * 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
        self.p3_head = nn.Conv2d(self.num_p3_features, self.num_p3_features * 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
        self.bn2 = nn.BatchNorm2d(self.num_p2_features * 4)
        self.bn3 = nn.BatchNorm2d(self.num_p3_features * 4)
        self.act2 = Swish()
        self.act3 = Swish()
        
        
        #self.fc = nn.Linear(self.num_features, num_total_classes)
        #self.fc = nn.Linear(self.backbone.last_linear.in_features, self.num_classes)
        
        self.fc_g = nn.Linear(self.backbone.last_linear.in_features, 168)
        self.fc_v = nn.Linear(self.backbone.last_linear.in_features, 11)
        self.fc_c = nn.Linear(self.backbone.last_linear.in_features, 7)
        self.fc_w = nn.Linear(self.backbone.last_linear.in_features, 1295)

        
        self.fc_aux1 = nn.Linear(self.num_p3_features * 4, self.num_classes)
        self.fc_aux2 = nn.Linear(self.num_p2_features * 4, self.num_classes)
        
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        
        #for fc in [self.fc, self.fc_aux1, self.fc_aux2]:
        #    nn.init.zeros_(fc.bias.data)
        for fc in [self.fc_g, self.fc_v, self.fc_c, self.fc_w, self.fc_aux1, self.fc_aux2]:
            nn.init.zeros_(fc.bias.data)

        print('init model4')
        
    def features(self, x):
        x = self.backbone.layer0(x); #print(x.size())
        x = self.backbone.layer1(x); #print(x.size())
        x = self.backbone.layer2(x); p2 = x; p2 = self.p2_head(p2); p2 = self.bn2(p2); p2 = self.act2(p2) #print(x.size())
        x = self.backbone.layer3(x); p3 = x; p3 = self.p3_head(p3); p3 = self.bn3(p3); p3 = self.act3(p3) #print(x.size())
        x = self.backbone.layer4(x); #print(x.size())
        return x, p2, p3
        
    def logits(self, x, p2, p3):
        x = self.avg_pool(x)
        #x = F.dropout2d(x, 0.2, self.training)
        x = torch.flatten(x, 1)
        
        p2 = self.avg_pool(p2)
        p2 = torch.flatten(p2, 1)
        
        p3 = self.avg_pool(p3)
        p3 = torch.flatten(p3, 1)
        
        #logits = self.fc(x)
        g, v, c, w = self.fc_g(x), self.fc_v(x), self.fc_c(x), self.fc_w(x)
        logits = torch.cat([g, v, c, w], 1)
        
        return logits, self.fc_aux1(p3), self.fc_aux2(p2)
    
    def forward(self, x):
        x = F.interpolate(x, size=(224,224), mode='bilinear', align_corners=False)
        for i in range(len(x)):
            transforms.functional.normalize(x[i], mean=MEAN, std=STD, inplace=True)
        x = torch.cat([x,x,x], 1)
        #x = self.conv0(x)
        #print(x.size())
        x, p2, p3 = self.features(x)
        x, logits_aux1, logits_aux2 = self.logits(x, p2, p3)

        return x, logits_aux1, logits_aux2
    
    def set_mode(self, mode, is_freeze_bn=True):
        self.mode = mode
        if mode in ['eval', 'valid', 'test']:
            self.eval()

        elif mode in ['train']:
            self.train()
        if is_freeze_bn == True:  ##freeze
            for m in self.modules():
                if isinstance(m, nn.BatchNorm2d):
                    m.eval()
                    m.weight.requires_grad = False
                    m.bias.requires_grad = False

# %%
# !ls ./model4-ckps/se_resnext50_32x4d
# Out:
# model4_se_resnext50_fold0_224_cv9976.pth
# model4_se_resnext50_fold0_224_cv9977.pth
# model4_se_resnext50_fold0_224_cv9978.pth
# model4_se_resnext50_fold0_224_cv998106.pth
# model4_se_resnext50_fold0_224_swa_cv998273.pth
# model4_se_resnext50_fold4_224_cv997979.pth
# model4_se_resnext50_fold4_224_swa_cv998285.pth

# %%
#!mkdir ./model4-finetune-ckps/se_resnext50_32x4d

# %%
def convert_model():
    model_old = BengaliNetOld()
    model_old.load_state_dict(torch.load('./model4-ckps/se_resnext50_32x4d/model4_se_resnext50_fold4_224_swa_cv998285.pth'))    
    
    model = BengaliNet()
    model.load_state_dict(torch.load('./model4-ckps/se_resnext50_32x4d/model4_se_resnext50_fold4_224_swa_cv998285.pth'), strict=False)
    model.fc_g.weight.data = model_old.fc.weight.data[:168] 
    model.fc_v.weight.data = model_old.fc.weight.data[168:168+11] 
    model.fc_c.weight.data = model_old.fc.weight.data[168+11:168+11+7] 
    model.fc_w.weight.data = model_old.fc.weight.data[168+11+7:] 
    model = model.cuda()
    model = amp.initialize(model, opt_level='O1')
    model = nn.DataParallel(model)
    validate(model, val_loader)
    torch.save(model.module.state_dict(), './model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth')

# %%
MODEL_DIR = './model4-finetune-ckps'
def create_model(args):
    model = BengaliNet()
    model_file = os.path.join(MODEL_DIR, args.backbone, args.ckp_name)

    parent_dir = os.path.dirname(model_file)
    if not os.path.exists(parent_dir):
        os.makedirs(parent_dir)

    print('model file: {}, exist: {}'.format(model_file, os.path.exists(model_file)))

    if os.path.exists(model_file):
        print('loading {}...'.format(model_file))
        model.load_state_dict(torch.load(model_file))
    
    return model, model_file

# %%
#bnet = BengaliNet('se_resnext50_32x4d').cuda()

# %%
#bnet(torch.randn((2, 1, 137, 236)).cuda()).size()

# %% [markdown]
# # train

# %%
round(1/9, 6)
# Out:
# 0.111111

# %%
import numpy as np
import sklearn.metrics
import torch


def calc_metrics(preds0, preds1, preds2, preds3, y):
    assert len(y) == len(preds0) == len(preds1) == len(preds2) == len(preds3)

    recall_grapheme = sklearn.metrics.recall_score(y[:, 0], preds0, average='macro')
    recall_vowel = sklearn.metrics.recall_score(y[:, 1], preds1, average='macro')
    recall_consonant = sklearn.metrics.recall_score(y[:, 2], preds2, average='macro')
    recall_word = sklearn.metrics.recall_score(y[:, 3], preds3, average='macro')
    
    scores = [recall_grapheme, recall_vowel, recall_consonant]
    final_recall_score = np.average(scores, weights=[2, 1, 1])
    
    old_recall_grapheme = sklearn.metrics.recall_score(preds0, y[:, 0], average='macro')
    old_recall_vowel = sklearn.metrics.recall_score(preds1, y[:, 1], average='macro')
    old_recall_consonant = sklearn.metrics.recall_score(preds2, y[:, 2], average='macro')
    old_recall_word = sklearn.metrics.recall_score(preds3, y[:, 3], average='macro')
    
    old_scores = [old_recall_grapheme, old_recall_vowel, old_recall_consonant]
    old_final_recall_score = np.average(old_scores, weights=[2, 1, 1])

    
    metrics = {}
    metrics['recall'] = round(final_recall_score, 6)
    metrics['recall_grapheme'] = round(recall_grapheme, 6)
    metrics['recall_vowel'] = round(recall_vowel, 6)
    metrics['recall_consonant'] = round(recall_consonant, 6)
    metrics['recall_word'] = round(recall_word, 6)
    
    metrics['acc_grapheme'] = round((preds0 == y[:, 0]).sum() / len(y), 6)
    metrics['acc_vowel'] = round((preds1 == y[:, 1]).sum() / len(y), 6)
    metrics['acc_consonant'] = round((preds2 == y[:, 2]).sum() / len(y), 6)
    metrics['acc_word'] = round((preds3 == y[:, 3]).sum() / len(y), 6)  
    
    metrics['old_recall'] = round(old_final_recall_score, 6)
    metrics['old_recall_grapheme'] = round(old_recall_grapheme, 6)
    
    return metrics

# %%
def criterion(outputs, y_true):
    # outputs: (N, 182)
    # y_true: (N, 3)
    
    outputs = torch.split(outputs, [168, 11, 7, 1295], dim=1)
    loss0 = F.cross_entropy(outputs[0], y_true[:, 0], reduction='mean')
    loss1 = F.cross_entropy(outputs[1], y_true[:, 1], reduction='mean')
    loss2 = F.cross_entropy(outputs[2], y_true[:, 2], reduction='mean')
    loss3 = F.cross_entropy(outputs[3], y_true[:, 3], reduction='mean')
    
    return loss0 + loss1 + loss2 + loss3 #, loss0.item(), loss1.item(), loss2.item()

# %%
def validate(model, val_loader):
    #model.eval()
    model.module.set_mode('valid', is_freeze_bn=True)

    loss0, loss1, loss2, loss3 = 0., 0., 0., 0.
    preds0, preds1, preds2, preds3 = [], [], [], []
    y_true = []
    with torch.no_grad():
        for x, y in val_loader:
            y_true.append(y)
            x, y = x.cuda(), y.cuda()
            outputs, _, _ = model(x)
            outputs = torch.split(outputs, [168, 11, 7, 1295], dim=1)
            
            preds0.append(torch.max(outputs[0], dim=1)[1])
            preds1.append(torch.max(outputs[1], dim=1)[1])
            preds2.append(torch.max(outputs[2], dim=1)[1])
            preds3.append(torch.max(outputs[3], dim=1)[1])
            loss0 += F.cross_entropy(outputs[0], y[:, 0], reduction='sum').item()
            loss1 += F.cross_entropy(outputs[1], y[:, 1], reduction='sum').item()
            loss2 += F.cross_entropy(outputs[2], y[:, 2], reduction='sum').item()
            loss3 += F.cross_entropy(outputs[3], y[:, 3], reduction='sum').item()
            
            # for debug
            #metrics = {}
            #metrics['loss_grapheme'] =  F.cross_entropy(outputs[0], y[:, 0], reduction='mean').item()
            #metrics['loss_vowel'] =  F.cross_entropy(outputs[1], y[:, 1], reduction='mean').item()
            #metrics['loss_consonant'] =  F.cross_entropy(outputs[2], y[:, 2], reduction='mean').item()
            #return metrics
    
    preds0 = torch.cat(preds0, 0).cpu().numpy()
    preds1 = torch.cat(preds1, 0).cpu().numpy()
    preds2 = torch.cat(preds2, 0).cpu().numpy()
    preds3 = torch.cat(preds3, 0).cpu().numpy()
    
    y_true = torch.cat(y_true, 0).numpy()
    
    #print('y_true:', y_true.shape)
    #print('preds0:', preds0.shape)
    
    metrics = calc_metrics(preds0, preds1, preds2, preds3, y_true)
    metrics['loss_grapheme'] = round(loss0 / val_loader.num, 6)
    metrics['loss_vowel'] = round(loss1 / val_loader.num, 6)
    metrics['loss_consonant'] = round(loss2 / val_loader.num, 6)
    metrics['loss_word'] = round(loss3 / val_loader.num, 6)
    
    return metrics

# %%
def get_lrs(optimizer):
    lrs = []
    for pgs in optimizer.state_dict()['param_groups']:
        lrs.append(pgs['lr'])
    lrs = ['{:.6f}'.format(x) for x in lrs]
    return lrs

# %%
def save_model(model, model_file):
    parent_dir = os.path.dirname(model_file)
    if not os.path.exists(parent_dir):
        os.makedirs(parent_dir)
    if isinstance(model, nn.DataParallel):
        torch.save(model.module.state_dict(), model_file)
    else:
        torch.save(model.state_dict(), model_file)

# %%
def mixup(data, targets, alpha=1):
    indices = torch.randperm(data.size(0))
    shuffled_data = data[indices]
    shuffled_targets = targets[indices]

    lam = np.random.beta(alpha, alpha)
    data = data * lam + shuffled_data * (1 - lam)
    targets = (targets, shuffled_targets, lam)

    return data, targets


def mixup_criterion(outputs, targets):
    targets1, targets2, lam = targets
    #criterion = nn.CrossEntropyLoss(reduction='mean')
    return lam * criterion(outputs, targets1) + (1 - lam) * criterion(outputs, targets2)

# %%
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %%
def rand_bbox_new(size, lam):
    H = size[2]
    W = size[3]

    x_margin_rate = 0.2

    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * (1-x_margin_rate*2) * cut_rat)
    cut_h = np.int(H * cut_rat)
    
    min_x_center = np.int(W * x_margin_rate + cut_w / 2)
    max_x_center = np.int(W * (1-x_margin_rate) - cut_w / 2)
    #print(min_x_center, max_x_center, lam, cut_w)
    min_y_center = cut_h // 2
    max_y_center = H - cut_h // 2
    if max_y_center == min_y_center:
        max_y_center += 1

    # uniform
    cx = np.random.randint(min_x_center, max_x_center)
    cy = np.random.randint(min_y_center, max_y_center)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)
    
    #print(bbx1, bbx2, bby1, bby2)

    return bbx1, bby1, bbx2, bby2

# %%
np.random.random()
# Out:
# 0.31993107523909714

# %%
from over9000.over9000 import Over9000
from over9000.radam import RAdam
from gridmask import GridMask

# %%
from cvcore.solver import WarmupCyclicalLR
def make_optimizer(model, base_lr=4e-4, weight_decay=0., weight_decay_bias=0., epsilon=1e-3):
    """
    Create optimizer with per-layer learning rate and weight decay.
    """
    params = []
    for key, value in model.named_parameters():
        if not value.requires_grad:
            continue
        lr = base_lr
        params += [{"params": [value], "lr": lr, "weight_decay": weight_decay_bias if 'bias' in key else weight_decay}]
    
    optimizer = torch.optim.AdamW(params, lr, eps=epsilon)
    return optimizer

# %%
def freeze_for_finetune(net):
    for param in net.parameters():
        param.requires_grad = False
    if finetune_class == 'grapheme_root':
        for param in net.fc_g.parameters():
            param.requires_grad = True
    elif finetune_class == 'vowel_diacritic':
        for param in net.fc_v.parameters():
            param.requires_grad = True
    else:
        for param in net.fc_c.parameters():
            param.requires_grad = True

# %%
import time
def train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid):
    train_loss = 0
    bg = time.time()

    for batch_idx, (img, orig_img, targets) in enumerate(train_loader):
        img, orig_img, targets  = img.cuda(), orig_img.cuda(), targets.cuda()
        batch_size = img.size(0)
        r = np.random.rand()

        #if True:
        #    outputs, outputs_aux1, outputs_aux2 = model(orig_img)
        #    loss = criterion(outputs, targets)
            #loss_aux1 = criterion(outputs_aux1, targets)
            #loss_aux2 = criterion(outputs_aux2, targets)
            #loss = loss_primary + (loss_aux1 + loss_aux2)*0.8
        if r < 0.5:
            # generate mixed sample
            lam = np.random.beta(args.beta, args.beta)
            rand_index = torch.randperm(img.size()[0]).cuda()
            target_a = targets
            target_b = targets[rand_index]
            bbx1, bby1, bbx2, bby2 = rand_bbox(img.size(), lam)
            #img[:, :, bby1:bby2, bbx1:bbx2] = img[rand_index, :, bby1:bby2, bbx1:bbx2] #for new cutmix
            img[:, :, bbx1:bbx2, bby1:bby2] = img[rand_index, :, bbx1:bbx2, bby1:bby2]
            
            # adjust lambda to exactly match pixel ratio
            lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (img.size()[-1] * img.size()[-2]))
            # compute output
            outputs, outputs_aux1, outputs_aux2 = model(img)
            loss = criterion(outputs, target_a) * lam + criterion(outputs, target_b) * (1. - lam)
            #loss_aux1 = criterion(outputs_aux1, target_a) * lam + criterion(outputs_aux1, target_b) * (1. - lam)
            #loss_aux2 = criterion(outputs_aux2, target_a) * lam + criterion(outputs_aux2, target_b) * (1. - lam)
            #loss = loss_primary + (loss_aux1 + loss_aux2)*0.8
        elif r > 0.5:
            img = grid(img)
            outputs, outputs_aux1, outputs_aux2 = model(img)
            loss = criterion(outputs, targets)
            #loss_aux1 = criterion(outputs_aux1, targets)
            #loss_aux2 = criterion(outputs_aux2, targets)
            #loss = loss_primary + (loss_aux1 + loss_aux2)*0.8
        else:
            orig_img, targets = mixup(orig_img, targets)
            outputs, outputs_aux1, outputs_aux2 = model(orig_img)
            loss = mixup_criterion(outputs, targets)
            #loss_aux1 = mixup_criterion(outputs_aux1, targets)
            #loss_aux2 = mixup_criterion(outputs_aux2, targets)
            #loss = loss_primary + (loss_aux1 + loss_aux2)*0.8
            #loss = criterion(outputs, targets)

        optimizer.zero_grad()
        with amp.scale_loss(loss, optimizer) as scaled_loss:
            scaled_loss.backward()
        #loss.backward()
        lr_scheduler(optimizer, batch_idx, epoch)
        optimizer.step()            
        
        current_lr = get_lrs(optimizer)

        train_loss += loss.item()
        print('\r {:4d} | {:.6f} | {:06d}/{} | {:.4f} | {:.4f} | {:.2f} |'.format(
            epoch, float(current_lr[0]), batch_size*(batch_idx+1), train_loader.num, 
            loss.item(), train_loss/(batch_idx+1), (time.time() - bg) / 60), end='')

# %%
import copy
best_metrics = 0.
best_metrics_swa = 0.


def validate_and_save(model, model_file, val_loader, save=False):
    global best_metrics
    best_key = 'recall'
    val_metrics = validate(model, val_loader)
    print('\nval:', val_metrics)
    
    if val_metrics[best_key] > best_metrics:
        best_metrics = val_metrics[best_key]
        if save:
            save_model(model, model_file)
            print('###>>>>> saved', model_file)
    model.module.set_mode('train', is_freeze_bn=True)

def validate_and_save_swa(model, model_file, val_loader, save=False):
    global best_metrics_swa
    best_key = 'recall'
    val_metrics = validate(model, val_loader)
    print('\nval:', val_metrics)
    
    if val_metrics[best_key] > best_metrics_swa:
        best_metrics_swa = val_metrics[best_key]
        if save:
            save_model(model, model_file)
            print('###>>>>> saved', model_file)
    model.module.set_mode('train', is_freeze_bn=True)



def train(args):
    model, model_file = create_model(args)
    model = model.cuda()
    
    freeze_for_finetune(model)

    swa_args = copy.deepcopy(args)
    swa_args.ckp_name = args.ckp_name + '_swa'
    swa_model, swa_model_file = create_model(swa_args)
    swa_model = swa_model.cuda()

    optimizer = make_optimizer(model)
    lr_scheduler = WarmupCyclicalLR(
        "cos", args.base_lr, args.num_epochs, iters_per_epoch=len(train_loader), warmup_epochs=args.warmup_epochs)
    
    [model, swa_model], optimizer = amp.initialize([model, swa_model], optimizer, opt_level="O1",verbosity=0)
    #[model, swa_model], optimizer = amp.initialize(
    #    [model, swa_model], optimizer, opt_level="O2",verbosity=0, keep_batchnorm_fp32=True)
    
    #opt_level="O2", keep_batchnorm_fp32=True
    
    if torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)
        swa_model = nn.DataParallel(swa_model)
    
    validate_and_save(model, model_file, val_loader, save=False)

    swa_model_loaded = False
    if os.path.exists(swa_model_file):
        swa_model_loaded = True
        validate_and_save_swa(swa_model, swa_model_file, val_loader, save=False)
        
    model.module.set_mode('train', is_freeze_bn=True)
    
    for cycle in range(1, args.num_cycles+1):
        print('CYCLE:', cycle)
        grid = GridMask(64, 128, rotate=15, ratio=0.6, mode=1, prob=1.)

        for epoch in range(args.start_epoch, args.num_epochs):
            grid.set_prob(epoch, args.st_epochs)
            train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid)
            validate_and_save(model, model_file, val_loader, save=True)
            
            if (epoch+1) == args.swa_start and cycle == 1:
                if not swa_model_loaded:
                    copy_model(swa_model, model)
                #swa_n = 0
                swa_n = args.swa_n
            if (epoch+1) >= args.swa_start and (epoch+1) % args.swa_freq == 0:
                print('SWA>>>:')
                moving_average(swa_model, model, 1.0 / (swa_n + 1))
                swa_n += 1
                bn_update(train_loader, swa_model)
                validate_and_save_swa(swa_model, swa_model_file, val_loader, save=True)

        #args.base_lr = 2e-4
        #args.num_epochs = 40
        #args.warmup_epochs = 1

        # reset scheduler at each cycle
        lr_scheduler = WarmupCyclicalLR(
            "cos", args.base_lr, args.num_epochs, iters_per_epoch=len(train_loader), warmup_epochs=args.warmup_epochs)
    del model
    del swa_model

# %%
#model, model_file = create_model(cfg)
#model(torch.randn(2,1,137,236))[0].size()

# %%
args = Namespace()
args.backbone = 'se_resnext50_32x4d'
args.ckp_name = 'model4_finetune_res50_fold4.pth'
args.base_lr = 8e-5
args.num_epochs = 25
args.start_epoch = 0
args.warmup_epochs = 5
args.num_cycles = 2
args.batch_size = 1536
args.val_batch_size = 1024
args.st_epochs = 5

args.swa_start = 3000
args.swa_freq = 3
args.swa_n = 5

args.beta = 1.0
args.cutmix_prob = 0.5

# %%
for i in range(100):
    for x in ['consonant_diacritic', 'vowel_diacritic', 'grapheme_root']:
        finetune_class = x
        train_loader, val_loader = get_train_val_loaders(
            batch_size=args.batch_size, val_batch_size=args.val_batch_size, ifold=4)
        train(args)
# Out:
# fold: 4
# (200840, 6)
# (200840, 32332)
# (160735, 6) (40105, 6)
# sampler length: torch.Size([160735])
# init model4
# model file: ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth, exist: True
# loading ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth...
# init model4
# model file: ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth_swa, exist: False
#
# val: {'recall': 0.997857, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998005, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# CYCLE: 1
#     0 | 0.000016 | 104055/160735 | 0.8942 | 5.4538 | 1.49 ||
# val: {'recall': 0.997922, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.99869, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998978, 'acc_word': 0.996783, 'old_recall': 0.997983, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.004622, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     1 | 0.000031 | 104055/160735 | 10.7407 | 5.4565 | 1.62 |
# val: {'recall': 0.997934, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998737, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998953, 'acc_word': 0.996783, 'old_recall': 0.997963, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.005302, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     2 | 0.000046 | 104055/160735 | 1.2534 | 4.8516 | 1.85 ||
# val: {'recall': 0.997939, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998756, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998903, 'acc_word': 0.996783, 'old_recall': 0.997667, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.006201, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     3 | 0.000060 | 104055/160735 | 10.0911 | 5.2499 | 2.05 |
# val: {'recall': 0.997917, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998667, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998878, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.006929, 'loss_word': 0.013658}
#     4 | 0.000072 | 104055/160735 | 8.3751 | 5.5970 | 2.23 ||
# val: {'recall': 0.997917, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998667, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998878, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.008609, 'loss_word': 0.013658}
#     5 | 0.000069 | 104055/160735 | 12.3935 | 5.3617 | 2.37 ||
# val: {'recall': 0.997908, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998634, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998853, 'acc_word': 0.996783, 'old_recall': 0.997904, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.011967, 'loss_word': 0.013658}
#     6 | 0.000066 | 104055/160735 | 8.1139 | 5.3422 | 2.41 |||
# val: {'recall': 0.997907, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998628, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998828, 'acc_word': 0.996783, 'old_recall': 0.997913, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.016234, 'loss_word': 0.013658}
#     7 | 0.000061 | 104055/160735 | 7.7907 | 4.7849 | 2.53 ||
# val: {'recall': 0.997907, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998628, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998828, 'acc_word': 0.996783, 'old_recall': 0.997913, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.020372, 'loss_word': 0.013658}
#     8 | 0.000057 | 104055/160735 | 1.7123 | 5.1512 | 2.35 |||
# val: {'recall': 0.997907, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998628, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998828, 'acc_word': 0.996783, 'old_recall': 0.997913, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.025495, 'loss_word': 0.013658}
#     9 | 0.000052 | 104055/160735 | 1.6017 | 5.4810 | 2.42 ||
# val: {'recall': 0.997905, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998622, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998803, 'acc_word': 0.996783, 'old_recall': 0.997904, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.030266, 'loss_word': 0.013658}
#    10 | 0.000048 | 104055/160735 | 10.4179 | 4.5905 | 2.57 |
# val: {'recall': 0.997905, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998622, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998803, 'acc_word': 0.996783, 'old_recall': 0.997904, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.031363, 'loss_word': 0.013658}
#    11 | 0.000043 | 104055/160735 | 6.4559 | 5.1106 | 2.46 ||
# val: {'recall': 0.997911, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.998644, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998778, 'acc_word': 0.996783, 'old_recall': 0.997874, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.035132, 'loss_word': 0.013658}
#    12 | 0.000042 | 009216/160735 | 1.7678 | 4.9492 | 0.22 | |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-b3c697dc9a92> in <module>
#       4         train_loader, val_loader = get_train_val_loaders(
#       5             batch_size=args.batch_size, val_batch_size=args.val_batch_size, ifold=4)
# ----> 6         train(args)
#
# <ipython-input-39-c8430504eb27> in train(args)
#      72         for epoch in range(args.start_epoch, args.num_epochs):
#      73             grid.set_prob(epoch, args.st_epochs)
# ---> 74             train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid)
#      75             validate_and_save(model, model_file, val_loader, save=True)
#      76
#
# <ipython-input-38-1d13624ae085> in train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid)
#      28             lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (img.size()[-1] * img.size()[-2]))
#      29             # compute output
# ---> 30             outputs, outputs_aux1, outputs_aux2 = model(img)
#      31             loss = criterion(outputs, target_a) * lam + criterion(outputs, target_b) * (1. - lam)
#      32             #loss_aux1 = criterion(outputs_aux1, target_a) * lam + criterion(outputs_aux1, target_b) * (1. - lam)
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     150             return self.module(*inputs[0], **kwargs[0])
#     151         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 152         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     153         return self.gather(outputs, self.output_device)
#     154
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     160
#     161     def parallel_apply(self, replicas, inputs, kwargs):
# --> 162         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     163
#     164     def gather(self, outputs, output_device):
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      75             thread.start()
#      76         for thread in threads:
# ---> 77             thread.join()
#      78     else:
#      79         _worker(0, modules[0], inputs[0], kwargs_tup[0], devices[0])
#
# /mnt/chicm/anaconda3/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /mnt/chicm/anaconda3/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
train_loader, val_loader = get_train_val_loaders(batch_size=args.batch_size, val_batch_size=args.val_batch_size, ifold=4)
# Out:
# fold: 4
# (200840, 6)
# (200840, 32332)
# (160735, 6) (40105, 6)
# sampler length: torch.Size([160735])

# %%
train(args)
# Out:
# init model4
# model file: ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth, exist: True
# loading ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth...
# init model4
# model file: ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth_swa, exist: False
#
# val: {'recall': 0.997822, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998603, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.999028, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998051, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.005395, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# CYCLE: 1
#     0 | 0.000020 | 104055/160735 | 1.0874 | 4.9390 | 1.49 ||
# val: {'recall': 0.99781, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998554, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998928, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998028, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.005591, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     1 | 0.000040 | 104055/160735 | 1.0722 | 5.4417 | 1.60 ||
# val: {'recall': 0.99781, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998554, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998928, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998028, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.006122, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     2 | 0.000059 | 104055/160735 | 9.5966 | 5.0740 | 1.84 ||
# val: {'recall': 0.99781, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998554, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998928, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998028, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.007189, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     3 | 0.000079 | 104055/160735 | 5.1549 | 5.2269 | 2.01 ||
# val: {'recall': 0.99781, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998554, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998928, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998028, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.010272, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     4 | 0.000097 | 104055/160735 | 8.8963 | 4.9994 | 2.25 ||
# val: {'recall': 0.997794, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998489, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998953, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998039, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.017682, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     5 | 0.000096 | 104055/160735 | 9.3730 | 5.0345 | 2.48 ||
# val: {'recall': 0.997826, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998618, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998928, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998001, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.03167, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     6 | 0.000095 | 104055/160735 | 9.6404 | 5.1993 | 2.42 ||
# val: {'recall': 0.997828, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998629, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998953, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998011, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.043463, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     7 | 0.000094 | 104055/160735 | 1.4793 | 4.4048 | 2.54 ||
# val: {'recall': 0.99785, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998716, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998953, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998006, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.047579, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     8 | 0.000092 | 104055/160735 | 12.9953 | 5.7745 | 2.24 |
# val: {'recall': 0.997849, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998711, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998953, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998004, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.058901, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     9 | 0.000090 | 104055/160735 | 1.6265 | 5.5909 | 2.27 ||
# val: {'recall': 0.997857, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998744, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998978, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998005, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.064602, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#    10 | 0.000089 | 104055/160735 | 9.3174 | 4.6779 | 2.46 ||
# val: {'recall': 0.997846, 'recall_grapheme': 0.997128, 'recall_vowel': 0.9987, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998928, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998001, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.060148, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    11 | 0.000086 | 104055/160735 | 1.3227 | 4.9839 | 2.51 ||
# val: {'recall': 0.997848, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998707, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997993, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.062361, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    12 | 0.000084 | 104055/160735 | 1.6115 | 5.1422 | 2.37 ||
# val: {'recall': 0.997851, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998718, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998928, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997999, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.062725, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    13 | 0.000082 | 104055/160735 | 10.1854 | 5.4910 | 2.31 ||
# val: {'recall': 0.997849, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998711, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998953, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998004, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.063981, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    14 | 0.000082 | 024576/160735 | 10.2413 | 5.3381 | 0.48 ||
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-aad596905035> in <module>
# ----> 1 train(args)
#
# <ipython-input-39-9bb7b908312e> in train(args)
#      72         for epoch in range(args.start_epoch, args.num_epochs):
#      73             grid.set_prob(epoch, args.st_epochs)
# ---> 74             train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid)
#      75             validate_and_save(model, model_file, val_loader, save=True)
#      76
#
# <ipython-input-38-1d13624ae085> in train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid)
#      34             #loss = loss_primary + (loss_aux1 + loss_aux2)*0.8
#      35         elif r > 0.5:
# ---> 36             img = grid(img)
#      37             outputs, outputs_aux1, outputs_aux2 = model(img)
#      38             loss = criterion(outputs, targets)
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /mnt/chicm/bengali/notebooks/gridmask.py in forward(self, x)
#      75         y = []
#      76         for i in range(n):
# ---> 77             y.append(self.grid(x[i]))
#      78         y = torch.cat(y).view(n,c,h,w)
#      79         return y
#
# /mnt/chicm/bengali/notebooks/gridmask.py in __call__(self, img)
#      50         mask = torch.from_numpy(mask).float().cuda()
#      51         if self.mode == 1:
# ---> 52             mask = 1-mask
#      53
#      54         mask = mask.expand_as(img)
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/apex/amp/wrap.py in wrapper(*args, **kwargs)
#      51
#      52         if len(types) <= 1:
# ---> 53             return orig_fn(*args, **kwargs)
#      54         elif len(types) == 2 and types == set(['HalfTensor', 'FloatTensor']):
#      55             new_args = utils.casted_args(cast_fn,
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/torch/tensor.py in __rsub__(self, other)
#     360
#     361     def __rsub__(self, other):
# --> 362         return _C._VariableFunctions.rsub(self, other)
#     363
#     364     def __rdiv__(self, other):
#
# KeyboardInterrupt:

# %%
train(args)
# Out:
# init model4
# model file: ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth, exist: True
# loading ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth...
# init model4
# model file: ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth_swa, exist: False
#
# val: {'recall': 0.997626, 'recall_grapheme': 0.996807, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997407, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998211, 'old_recall_grapheme': 0.997459, 'loss_grapheme': 0.011571, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# CYCLE: 1
#     0 | 0.000020 | 155587/160735 | 3.3286 | 5.2670 | 1.51 |||
# val: {'recall': 0.99763, 'recall_grapheme': 0.996815, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998131, 'old_recall_grapheme': 0.9973, 'loss_grapheme': 0.011611, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     1 | 0.000040 | 155587/160735 | 1.1047 | 6.2764 | 1.60 |||
# val: {'recall': 0.997708, 'recall_grapheme': 0.996971, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997998, 'old_recall_grapheme': 0.997034, 'loss_grapheme': 0.012163, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     2 | 0.000059 | 155587/160735 | 1.0141 | 5.5982 | 1.71 ||
# val: {'recall': 0.997682, 'recall_grapheme': 0.99692, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997933, 'old_recall_grapheme': 0.996904, 'loss_grapheme': 0.013008, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     3 | 0.000079 | 155587/160735 | 9.9810 | 5.2114 | 1.89 |||
# val: {'recall': 0.997786, 'recall_grapheme': 0.997128, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998023, 'old_recall_grapheme': 0.997084, 'loss_grapheme': 0.013992, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# ###>>>>> saved ./model4-finetune-ckps/se_resnext50_32x4d/model4_finetune_res50_fold4.pth
#     4 | 0.000097 | 155587/160735 | 12.5527 | 6.1722 | 1.94 |
# val: {'recall': 0.997765, 'recall_grapheme': 0.997086, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99787, 'old_recall_grapheme': 0.996777, 'loss_grapheme': 0.016565, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     5 | 0.000096 | 155587/160735 | 1.3921 | 5.9132 | 1.98 ||
# val: {'recall': 0.997772, 'recall_grapheme': 0.997101, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997307, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997992, 'old_recall_grapheme': 0.997022, 'loss_grapheme': 0.024067, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     6 | 0.000095 | 155587/160735 | 1.8086 | 5.6216 | 2.10 ||
# val: {'recall': 0.997756, 'recall_grapheme': 0.997068, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99797, 'old_recall_grapheme': 0.996978, 'loss_grapheme': 0.033167, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     7 | 0.000094 | 155587/160735 | 1.3784 | 6.1743 | 2.00 ||
# val: {'recall': 0.997574, 'recall_grapheme': 0.996705, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997883, 'old_recall_grapheme': 0.996804, 'loss_grapheme': 0.047449, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     8 | 0.000092 | 155587/160735 | 11.2615 | 4.7418 | 2.23 |
# val: {'recall': 0.997575, 'recall_grapheme': 0.996707, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997904, 'old_recall_grapheme': 0.996846, 'loss_grapheme': 0.056569, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     9 | 0.000090 | 155587/160735 | 1.3839 | 5.3212 | 2.12 ||
# val: {'recall': 0.997582, 'recall_grapheme': 0.99672, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997929, 'old_recall_grapheme': 0.996895, 'loss_grapheme': 0.067621, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    10 | 0.000089 | 155587/160735 | 1.3751 | 6.1190 | 1.96 |||
# val: {'recall': 0.997528, 'recall_grapheme': 0.996613, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997931, 'old_recall_grapheme': 0.996899, 'loss_grapheme': 0.082277, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    11 | 0.000086 | 155587/160735 | 9.3031 | 4.9262 | 2.24 ||
# val: {'recall': 0.997627, 'recall_grapheme': 0.99681, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997963, 'old_recall_grapheme': 0.996962, 'loss_grapheme': 0.08221, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    12 | 0.000084 | 155587/160735 | 1.5576 | 5.6878 | 2.10 ||
# val: {'recall': 0.997634, 'recall_grapheme': 0.996823, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997918, 'old_recall_grapheme': 0.996873, 'loss_grapheme': 0.089374, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    13 | 0.000082 | 155587/160735 | 10.9849 | 5.3727 | 2.06 |
# val: {'recall': 0.997613, 'recall_grapheme': 0.996782, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997913, 'old_recall_grapheme': 0.996864, 'loss_grapheme': 0.09579, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    14 | 0.000079 | 155587/160735 | 1.4404 | 5.3654 | 2.08 ||
# val: {'recall': 0.997712, 'recall_grapheme': 0.99698, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.9979, 'old_recall_grapheme': 0.996836, 'loss_grapheme': 0.096841, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    15 | 0.000077 | 155587/160735 | 1.4209 | 5.7442 | 2.02 ||
# val: {'recall': 0.997682, 'recall_grapheme': 0.99692, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997307, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997913, 'old_recall_grapheme': 0.996864, 'loss_grapheme': 0.103789, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    16 | 0.000074 | 155587/160735 | 1.3613 | 5.2847 | 2.15 ||
# val: {'recall': 0.997647, 'recall_grapheme': 0.996849, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997935, 'old_recall_grapheme': 0.996908, 'loss_grapheme': 0.103893, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    17 | 0.000071 | 155587/160735 | 10.4843 | 5.6091 | 2.09 |
# val: {'recall': 0.997718, 'recall_grapheme': 0.996993, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997976, 'old_recall_grapheme': 0.99699, 'loss_grapheme': 0.107043, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    18 | 0.000068 | 155587/160735 | 3.0926 | 5.8523 | 1.97 |||
# val: {'recall': 0.997692, 'recall_grapheme': 0.99694, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.9979, 'old_recall_grapheme': 0.996837, 'loss_grapheme': 0.111752, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    19 | 0.000065 | 155587/160735 | 1.4345 | 5.3452 | 2.14 |||
# val: {'recall': 0.997724, 'recall_grapheme': 0.997004, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997929, 'old_recall_grapheme': 0.996895, 'loss_grapheme': 0.109422, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    20 | 0.000062 | 155587/160735 | 9.6982 | 5.1912 | 2.41 |||
# val: {'recall': 0.997641, 'recall_grapheme': 0.996838, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997918, 'old_recall_grapheme': 0.996874, 'loss_grapheme': 0.105987, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    21 | 0.000059 | 155587/160735 | 1.2164 | 5.4559 | 2.03 ||
# val: {'recall': 0.9976, 'recall_grapheme': 0.996757, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.9978, 'old_recall_grapheme': 0.996638, 'loss_grapheme': 0.107127, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    22 | 0.000056 | 155587/160735 | 1.2550 | 5.3560 | 2.08 |||
# val: {'recall': 0.997706, 'recall_grapheme': 0.996969, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997976, 'old_recall_grapheme': 0.996989, 'loss_grapheme': 0.107022, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    23 | 0.000053 | 155587/160735 | 2.4142 | 5.2679 | 2.03 ||
# val: {'recall': 0.997688, 'recall_grapheme': 0.996933, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99795, 'old_recall_grapheme': 0.996936, 'loss_grapheme': 0.106853, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    24 | 0.000050 | 155587/160735 | 7.5464 | 5.5454 | 2.12 ||
# val: {'recall': 0.997731, 'recall_grapheme': 0.997017, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997357, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.998024, 'old_recall_grapheme': 0.997085, 'loss_grapheme': 0.106328, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    25 | 0.000047 | 155587/160735 | 10.9349 | 5.4720 | 2.15 |
# val: {'recall': 0.997737, 'recall_grapheme': 0.99703, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997357, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997996, 'old_recall_grapheme': 0.997029, 'loss_grapheme': 0.106454, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    26 | 0.000044 | 155587/160735 | 6.0626 | 5.8494 | 2.00 ||
# val: {'recall': 0.997724, 'recall_grapheme': 0.997004, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997866, 'old_recall_grapheme': 0.99677, 'loss_grapheme': 0.109697, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    27 | 0.000041 | 155587/160735 | 1.2881 | 5.6043 | 2.08 ||
# val: {'recall': 0.9977, 'recall_grapheme': 0.996957, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997948, 'old_recall_grapheme': 0.996934, 'loss_grapheme': 0.109521, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    28 | 0.000038 | 155587/160735 | 1.1834 | 5.5328 | 2.02 ||
# val: {'recall': 0.997665, 'recall_grapheme': 0.996885, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997952, 'old_recall_grapheme': 0.99694, 'loss_grapheme': 0.109702, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    29 | 0.000035 | 155587/160735 | 10.1862 | 5.4129 | 2.06 |
# val: {'recall': 0.997693, 'recall_grapheme': 0.996942, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997941, 'old_recall_grapheme': 0.99692, 'loss_grapheme': 0.108961, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    30 | 0.000032 | 155587/160735 | 7.5695 | 5.5723 | 2.15 |||
# val: {'recall': 0.997653, 'recall_grapheme': 0.996861, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997905, 'old_recall_grapheme': 0.996848, 'loss_grapheme': 0.108649, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    31 | 0.000029 | 155587/160735 | 1.2286 | 5.4683 | 2.05 ||
# val: {'recall': 0.997654, 'recall_grapheme': 0.996864, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997938, 'old_recall_grapheme': 0.996913, 'loss_grapheme': 0.109045, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    32 | 0.000026 | 155587/160735 | 1.5326 | 5.6343 | 2.01 ||
# val: {'recall': 0.997675, 'recall_grapheme': 0.996907, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997981, 'old_recall_grapheme': 0.997, 'loss_grapheme': 0.108986, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    33 | 0.000023 | 155587/160735 | 5.2516 | 5.4479 | 2.04 |||
# val: {'recall': 0.997645, 'recall_grapheme': 0.996845, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99784, 'old_recall_grapheme': 0.996717, 'loss_grapheme': 0.109405, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    34 | 0.000021 | 155587/160735 | 1.5824 | 5.7244 | 2.02 ||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996873, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997951, 'old_recall_grapheme': 0.996939, 'loss_grapheme': 0.109749, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    35 | 0.000018 | 155587/160735 | 10.0952 | 5.2902 | 2.13 ||
# val: {'recall': 0.997663, 'recall_grapheme': 0.996883, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997973, 'old_recall_grapheme': 0.996984, 'loss_grapheme': 0.10886, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    36 | 0.000016 | 155587/160735 | 9.7338 | 5.7662 | 1.97 ||
# val: {'recall': 0.997698, 'recall_grapheme': 0.996953, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99795, 'old_recall_grapheme': 0.996938, 'loss_grapheme': 0.110192, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    37 | 0.000014 | 155587/160735 | 1.4314 | 5.5361 | 2.19 ||
# val: {'recall': 0.997725, 'recall_grapheme': 0.997007, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997977, 'old_recall_grapheme': 0.99699, 'loss_grapheme': 0.109834, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    38 | 0.000011 | 155587/160735 | 7.7918 | 5.3068 | 2.09 ||
# val: {'recall': 0.997712, 'recall_grapheme': 0.99698, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997307, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99796, 'old_recall_grapheme': 0.996958, 'loss_grapheme': 0.109495, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    39 | 0.000010 | 155587/160735 | 11.1064 | 5.3717 | 2.12 ||
# val: {'recall': 0.997725, 'recall_grapheme': 0.997007, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997977, 'old_recall_grapheme': 0.99699, 'loss_grapheme': 0.109015, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    40 | 0.000008 | 155587/160735 | 6.5868 | 5.3828 | 2.02 ||
# val: {'recall': 0.997709, 'recall_grapheme': 0.996974, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997957, 'old_recall_grapheme': 0.996951, 'loss_grapheme': 0.108843, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    41 | 0.000006 | 155587/160735 | 11.4387 | 5.4457 | 2.02 ||
# val: {'recall': 0.997712, 'recall_grapheme': 0.99698, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997307, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997986, 'old_recall_grapheme': 0.99701, 'loss_grapheme': 0.108816, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    42 | 0.000005 | 155587/160735 | 1.9470 | 5.6802 | 2.06 ||
# val: {'recall': 0.997725, 'recall_grapheme': 0.997007, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997977, 'old_recall_grapheme': 0.99699, 'loss_grapheme': 0.108805, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    43 | 0.000004 | 155587/160735 | 7.0275 | 5.6641 | 1.98 ||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.996926, 'loss_grapheme': 0.1087, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    44 | 0.000002 | 155587/160735 | 1.4500 | 4.9729 | 2.13 ||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.996926, 'loss_grapheme': 0.108483, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    45 | 0.000002 | 155587/160735 | 1.3837 | 5.7979 | 1.90 ||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.996926, 'loss_grapheme': 0.108657, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    46 | 0.000001 | 155587/160735 | 2.7962 | 5.9245 | 1.98 ||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.996926, 'loss_grapheme': 0.108725, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    47 | 0.000000 | 155587/160735 | 9.0509 | 5.4472 | 2.11 ||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.996926, 'loss_grapheme': 0.108734, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    48 | 0.000000 | 155587/160735 | 10.6187 | 5.5479 | 2.03 |
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.996926, 'loss_grapheme': 0.108739, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    49 | 0.000000 | 155587/160735 | 4.6818 | 5.4690 | 2.03 |||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997945, 'old_recall_grapheme': 0.996926, 'loss_grapheme': 0.108742, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
# CYCLE: 2
#     0 | 0.000020 | 155587/160735 | 9.9898 | 5.4511 | 1.48 ||
# val: {'recall': 0.997698, 'recall_grapheme': 0.996953, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99795, 'old_recall_grapheme': 0.996938, 'loss_grapheme': 0.109659, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     1 | 0.000040 | 155587/160735 | 5.9637 | 5.6890 | 1.57 ||
# val: {'recall': 0.997666, 'recall_grapheme': 0.996887, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997954, 'old_recall_grapheme': 0.996946, 'loss_grapheme': 0.110124, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     2 | 0.000059 | 155587/160735 | 7.9922 | 5.1797 | 1.71 |||
# val: {'recall': 0.997678, 'recall_grapheme': 0.996911, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997845, 'old_recall_grapheme': 0.996728, 'loss_grapheme': 0.10783, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     3 | 0.000079 | 155587/160735 | 2.7247 | 5.5512 | 1.80 ||
# val: {'recall': 0.997666, 'recall_grapheme': 0.996888, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997307, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997956, 'old_recall_grapheme': 0.99695, 'loss_grapheme': 0.110657, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     4 | 0.000097 | 155587/160735 | 1.5037 | 5.4097 | 1.97 ||
# val: {'recall': 0.99766, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997964, 'old_recall_grapheme': 0.996965, 'loss_grapheme': 0.107413, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     5 | 0.000096 | 155587/160735 | 10.2381 | 5.4465 | 1.95 |
# val: {'recall': 0.997643, 'recall_grapheme': 0.996842, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997792, 'old_recall_grapheme': 0.996622, 'loss_grapheme': 0.108443, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     6 | 0.000095 | 155587/160735 | 10.4708 | 5.3765 | 2.11 |
# val: {'recall': 0.99771, 'recall_grapheme': 0.996976, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997332, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997943, 'old_recall_grapheme': 0.996924, 'loss_grapheme': 0.106556, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     7 | 0.000094 | 155587/160735 | 1.3468 | 5.4830 | 2.02 ||
# val: {'recall': 0.997669, 'recall_grapheme': 0.996895, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997282, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997867, 'old_recall_grapheme': 0.996771, 'loss_grapheme': 0.107497, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     8 | 0.000092 | 155587/160735 | 2.5259 | 5.0448 | 2.25 |||
# val: {'recall': 0.997639, 'recall_grapheme': 0.996834, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997182, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99784, 'old_recall_grapheme': 0.996717, 'loss_grapheme': 0.10168, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#     9 | 0.000090 | 155587/160735 | 7.5086 | 5.0123 | 2.09 |||
# val: {'recall': 0.997656, 'recall_grapheme': 0.996868, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997937, 'old_recall_grapheme': 0.996911, 'loss_grapheme': 0.100066, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    10 | 0.000089 | 155587/160735 | 12.2031 | 5.5774 | 2.00 |
# val: {'recall': 0.997702, 'recall_grapheme': 0.996959, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997257, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997797, 'old_recall_grapheme': 0.99663, 'loss_grapheme': 0.104644, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    11 | 0.000086 | 155587/160735 | 1.4934 | 5.8059 | 1.93 ||
# val: {'recall': 0.997649, 'recall_grapheme': 0.996854, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997842, 'old_recall_grapheme': 0.996722, 'loss_grapheme': 0.108918, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    12 | 0.000084 | 155587/160735 | 1.3977 | 4.8719 | 2.15 ||
# val: {'recall': 0.997613, 'recall_grapheme': 0.996782, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997816, 'old_recall_grapheme': 0.996669, 'loss_grapheme': 0.101926, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    13 | 0.000082 | 155587/160735 | 2.0201 | 4.8861 | 2.22 ||
# val: {'recall': 0.997642, 'recall_grapheme': 0.996839, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997891, 'old_recall_grapheme': 0.99682, 'loss_grapheme': 0.097145, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    14 | 0.000079 | 155587/160735 | 4.1439 | 5.2511 | 2.12 ||
# val: {'recall': 0.997621, 'recall_grapheme': 0.996797, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997879, 'old_recall_grapheme': 0.996795, 'loss_grapheme': 0.098529, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    15 | 0.000077 | 155587/160735 | 1.4945 | 5.2646 | 2.09 ||
# val: {'recall': 0.997644, 'recall_grapheme': 0.996845, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.99786, 'old_recall_grapheme': 0.996758, 'loss_grapheme': 0.099164, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    16 | 0.000074 | 155587/160735 | 2.0744 | 5.6505 | 2.02 ||
# val: {'recall': 0.997644, 'recall_grapheme': 0.996844, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997182, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.9978, 'old_recall_grapheme': 0.996637, 'loss_grapheme': 0.102983, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    17 | 0.000071 | 155587/160735 | 1.2843 | 5.7314 | 2.08 ||
# val: {'recall': 0.997605, 'recall_grapheme': 0.996766, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997083, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997794, 'old_recall_grapheme': 0.996625, 'loss_grapheme': 0.103869, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    18 | 0.000068 | 155587/160735 | 6.3492 | 5.0583 | 2.16 ||
# val: {'recall': 0.997667, 'recall_grapheme': 0.996889, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997814, 'old_recall_grapheme': 0.996665, 'loss_grapheme': 0.099997, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    19 | 0.000065 | 155587/160735 | 7.7594 | 5.9085 | 2.01 ||
# val: {'recall': 0.99765, 'recall_grapheme': 0.996856, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997844, 'old_recall_grapheme': 0.996725, 'loss_grapheme': 0.102888, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    20 | 0.000062 | 155587/160735 | 2.6824 | 5.7541 | 2.03 ||
# val: {'recall': 0.997654, 'recall_grapheme': 0.996864, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997182, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997834, 'old_recall_grapheme': 0.996705, 'loss_grapheme': 0.105014, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    21 | 0.000059 | 155587/160735 | 10.2419 | 5.7389 | 2.00 |
# val: {'recall': 0.997643, 'recall_grapheme': 0.996842, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997749, 'old_recall_grapheme': 0.996536, 'loss_grapheme': 0.105182, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    22 | 0.000056 | 155587/160735 | 9.1052 | 5.0884 | 2.13 ||
# val: {'recall': 0.997652, 'recall_grapheme': 0.99686, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997865, 'old_recall_grapheme': 0.996767, 'loss_grapheme': 0.101771, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    23 | 0.000053 | 155587/160735 | 9.1804 | 5.8341 | 1.98 ||
# val: {'recall': 0.997653, 'recall_grapheme': 0.996862, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997232, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997794, 'old_recall_grapheme': 0.996625, 'loss_grapheme': 0.103744, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    24 | 0.000050 | 155587/160735 | 2.1782 | 5.1421 | 2.03 |||
# val: {'recall': 0.99763, 'recall_grapheme': 0.996816, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997688, 'old_recall_grapheme': 0.996413, 'loss_grapheme': 0.101718, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    25 | 0.000047 | 155587/160735 | 1.5439 | 4.9119 | 2.11 ||
# val: {'recall': 0.997659, 'recall_grapheme': 0.996875, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997759, 'old_recall_grapheme': 0.996554, 'loss_grapheme': 0.098712, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    26 | 0.000044 | 155587/160735 | 0.3372 | 6.2393 | 1.91 ||
# val: {'recall': 0.997638, 'recall_grapheme': 0.996833, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997133, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997718, 'old_recall_grapheme': 0.996473, 'loss_grapheme': 0.105151, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    27 | 0.000041 | 155587/160735 | 1.3371 | 5.3892 | 2.05 |||
# val: {'recall': 0.997637, 'recall_grapheme': 0.996829, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997842, 'old_recall_grapheme': 0.996721, 'loss_grapheme': 0.103715, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    28 | 0.000038 | 155587/160735 | 7.4943 | 5.2412 | 2.09 |||
# val: {'recall': 0.997614, 'recall_grapheme': 0.996783, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997659, 'old_recall_grapheme': 0.996355, 'loss_grapheme': 0.102051, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    29 | 0.000035 | 155587/160735 | 10.5528 | 5.8702 | 2.03 ||
# val: {'recall': 0.997624, 'recall_grapheme': 0.996804, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997825, 'old_recall_grapheme': 0.996688, 'loss_grapheme': 0.104105, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    30 | 0.000032 | 155587/160735 | 6.9429 | 5.4024 | 2.04 ||
# val: {'recall': 0.997648, 'recall_grapheme': 0.996852, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997737, 'old_recall_grapheme': 0.996511, 'loss_grapheme': 0.103124, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    31 | 0.000029 | 155587/160735 | 1.5567 | 5.4864 | 2.04 ||
# val: {'recall': 0.997654, 'recall_grapheme': 0.996864, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997207, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997762, 'old_recall_grapheme': 0.996561, 'loss_grapheme': 0.102655, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    32 | 0.000026 | 155587/160735 | 9.3569 | 5.5327 | 2.11 |||
# val: {'recall': 0.997627, 'recall_grapheme': 0.99681, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997713, 'old_recall_grapheme': 0.996463, 'loss_grapheme': 0.103177, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    33 | 0.000023 | 155587/160735 | 4.7178 | 5.2820 | 2.00 ||
# val: {'recall': 0.997619, 'recall_grapheme': 0.996793, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997083, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997716, 'old_recall_grapheme': 0.99647, 'loss_grapheme': 0.102412, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    34 | 0.000021 | 155587/160735 | 1.3812 | 5.1803 | 2.11 ||
# val: {'recall': 0.997623, 'recall_grapheme': 0.996801, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997732, 'old_recall_grapheme': 0.996501, 'loss_grapheme': 0.101817, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    35 | 0.000018 | 155587/160735 | 1.4622 | 5.3937 | 2.08 ||
# val: {'recall': 0.997633, 'recall_grapheme': 0.996822, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997133, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997738, 'old_recall_grapheme': 0.996514, 'loss_grapheme': 0.101788, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    36 | 0.000016 | 155587/160735 | 4.6105 | 5.0170 | 2.10 ||
# val: {'recall': 0.997633, 'recall_grapheme': 0.996822, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997133, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997738, 'old_recall_grapheme': 0.996514, 'loss_grapheme': 0.100544, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    37 | 0.000014 | 155587/160735 | 1.2998 | 5.7028 | 2.01 ||
# val: {'recall': 0.997623, 'recall_grapheme': 0.996801, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997732, 'old_recall_grapheme': 0.996501, 'loss_grapheme': 0.101068, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    38 | 0.000011 | 155587/160735 | 1.5755 | 5.9788 | 1.95 ||
# val: {'recall': 0.997631, 'recall_grapheme': 0.996819, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997738, 'old_recall_grapheme': 0.996514, 'loss_grapheme': 0.102391, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    39 | 0.000010 | 155587/160735 | 8.4376 | 5.6491 | 1.88 ||
# val: {'recall': 0.997627, 'recall_grapheme': 0.99681, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997133, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997735, 'old_recall_grapheme': 0.996507, 'loss_grapheme': 0.102557, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    40 | 0.000008 | 155587/160735 | 2.1583 | 5.3335 | 2.10 ||
# val: {'recall': 0.997621, 'recall_grapheme': 0.996798, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997727, 'old_recall_grapheme': 0.996492, 'loss_grapheme': 0.102365, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    41 | 0.000006 | 155587/160735 | 10.5652 | 5.9883 | 2.02 ||
# val: {'recall': 0.997623, 'recall_grapheme': 0.996801, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997108, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997732, 'old_recall_grapheme': 0.996501, 'loss_grapheme': 0.10269, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    42 | 0.000005 | 155587/160735 | 12.0984 | 5.5691 | 2.01 |
# val: {'recall': 0.997627, 'recall_grapheme': 0.99681, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997133, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997736, 'old_recall_grapheme': 0.996509, 'loss_grapheme': 0.102708, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    43 | 0.000004 | 155587/160735 | 9.4604 | 5.3605 | 2.09 ||
# val: {'recall': 0.99764, 'recall_grapheme': 0.996836, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997157, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997752, 'old_recall_grapheme': 0.996541, 'loss_grapheme': 0.102636, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    44 | 0.000002 | 155587/160735 | 1.6120 | 5.4673 | 2.04 ||
# val: {'recall': 0.997636, 'recall_grapheme': 0.996828, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997133, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997748, 'old_recall_grapheme': 0.996534, 'loss_grapheme': 0.10262, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    45 | 0.000002 | 155587/160735 | 6.9285 | 5.3656 | 2.11 |||
# val: {'recall': 0.997627, 'recall_grapheme': 0.99681, 'recall_vowel': 0.998458, 'recall_consonant': 0.99843, 'recall_word': 0.996776, 'acc_grapheme': 0.997133, 'acc_vowel': 0.998903, 'acc_consonant': 0.998928, 'acc_word': 0.996783, 'old_recall': 0.997736, 'old_recall_grapheme': 0.996509, 'loss_grapheme': 0.102533, 'loss_vowel': 0.005376, 'loss_consonant': 0.004365, 'loss_word': 0.013658}
#    46 | 0.000001 | 147456/160735 | 4.2799 | 5.4714 | 1.89 ||
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-aad596905035> in <module>
# ----> 1 train(args)
#
# <ipython-input-44-9bb7b908312e> in train(args)
#      72         for epoch in range(args.start_epoch, args.num_epochs):
#      73             grid.set_prob(epoch, args.st_epochs)
# ---> 74             train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid)
#      75             validate_and_save(model, model_file, val_loader, save=True)
#      76
#
# <ipython-input-38-98b588f75273> in train_epoch(args, model, train_loader, epoch, optimizer, lr_scheduler, grid)
#      34             #loss = loss_primary + (loss_aux1 + loss_aux2)*0.8
#      35         elif r > 0.7:
# ---> 36             img = grid(img)
#      37             outputs, outputs_aux1, outputs_aux2 = model(img)
#      38             loss = criterion(outputs, targets)
#
# /mnt/chicm/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /mnt/chicm/bengali/notebooks/gridmask.py in forward(self, x)
#      75         y = []
#      76         for i in range(n):
# ---> 77             y.append(self.grid(x[i]))
#      78         y = torch.cat(y).view(n,c,h,w)
#      79         return y
#
# KeyboardInterrupt:
